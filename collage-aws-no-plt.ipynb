# %% [markdown]
# # Notes
#
# - usually takes 6-7 minutes to run depending on amount of data that is being fetched
# - gets spotify data using spotipy library
# - saves data
#   - locally
#   - in aws
# - does not display collage in matplotlib

# %%
# !export

# %% [markdown]
# #### Module installs

# %%
# !pip3 install git+https://github.com/plamere/spotipy.git --upgrade
# !pip3 install image
# !pip3 install Send2Trash

# %% [markdown]
# #### Imports

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

import os
import urllib.request

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image

import requests
from io import BytesIO
import boto3

from datetime import datetime

# %%
print('time: '+ str(datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
# Out:
# time: 2024-06-23 10:28:48

# %% [markdown]
# #### Spotipy set up

# %%
client_id = os.environ['SPOTIFY_CLIENT_ID']
client_secret = os.environ['SPOTIFY_CLIENT_SECRET']
redirect_URI = os.environ['SPOTIFY_REDIRECT_URI']
username = os.environ['SPOTIFY_USERNAME']

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

scope = 'user-library-read user-read-currently-playing user-read-playback-state user-read-recently-played'
token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_URI)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
# usually takes some time to execute...

url_list = []

C = 25
R = 9
limit = C
amount = C*R*2

for i in range(0, amount, limit):
    saved_tracks = sp.current_user_saved_tracks(limit=limit, offset=i)
    
    for t in saved_tracks['items']:
        track = t['track']
        track_album = track['album']
        url = track_album['images'][0]['url']
        url_dict = {
            'id': track_album['id'],
            'name': track_album['name'],
            'url': url
        }
        url_list.append(url_dict)
        
    print('Progress: {}/{}'.format(i+limit, amount), end='\r')
# Out:
# Progress: 450/450

# %%
df = pd.DataFrame(url_list)
df.drop_duplicates(keep='first', inplace=True) # drop duplicate albums
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)
df.head()
# Out:
#                        id                                               name  \
# 0  6kZ42qRrzov54LcAk4onW9                             Red (Taylor's Version)
# 1  3RE8NUULcBzFvVtCmlI4lb                   Gettin' Ready (Expanded Edition)
# 2  7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 3  4UlGauD7ROb3YbVOFMgW5u                                      ANTI (Deluxe)
# 4  6WW8YiLb4jM9GiSbPUPBfu  Anyone But You (Original Motion Picture Soundt...
#
#                                                  url
# 0  https://i.scdn.co/image/ab67616d0000b273318443...
# 1  https://i.scdn.co/image/ab67616d0000b2739f0636...
# 2  https://i.scdn.co/image/ab67616d0000b27371d62e...
# 3  https://i.scdn.co/image/ab67616d0000b27333c6b9...
# 4  https://i.scdn.co/image/ab67616d0000b273247f10...

# %%
df.shape
# Out:
# (411, 3)

# %%
aws_access_key_id = os.environ['AWS_ACCESS_KEY_ID']
aws_secret_access_key = os.environ['AWS_SECRET_ACCESS_KEY']
bucket_name = os.environ['AWS_BUCKET_NAME']
img_folder_name = os.environ['AWS_BUCKET_FOLDER_NAME']

def create_client():
    return boto3.client(
        's3',
        aws_access_key_id=aws_access_key_id,
        aws_secret_access_key=aws_secret_access_key
    )
    
def create_session():
    return boto3.Session(
        aws_access_key_id=aws_access_key_id,
        aws_secret_access_key=aws_secret_access_key
    )
    
def create_client_from_session():
    boto_session = create_session()
    return boto_session.client('s3')
    
def create_resource_from_session():
    boto_session = create_session()
    return boto_session.resource('s3')
    
def create_bucket(bucket_name):
    s3 = create_resource_from_session()
    return s3.Bucket(bucket_name)

# %%
# create AWS S3 folder

response = create_client().put_object(
    Bucket=bucket_name,
    Key=img_folder_name
)
print(response)

bucket = create_bucket(bucket_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'AYA8MAMRG0JPE180', 'HostId': 'Zrzq7l3LSY6r/cfcufSMMCAwNZJaOcQ5roy8IAJSGGF0/vyku5rz7L+0grZwkAYjD96EV+S1eUiyIWnssgrnvA==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Zrzq7l3LSY6r/cfcufSMMCAwNZJaOcQ5roy8IAJSGGF0/vyku5rz7L+0grZwkAYjD96EV+S1eUiyIWnssgrnvA==', 'x-amz-request-id': 'AYA8MAMRG0JPE180', 'date': 'Sun, 23 Jun 2024 15:28:57 GMT', 'x-amz-server-side-encryption': 'AES256', 'etag': '"d41d8cd98f00b204e9800998ecf8427e"', 'server': 'AmazonS3', 'content-length': '0'}, 'RetryAttempts': 1}, 'ETag': '"d41d8cd98f00b204e9800998ecf8427e"', 'ServerSideEncryption': 'AES256'}

# %%
print('time: '+ str(datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
# Out:
# time: 2024-06-23 10:28:56

# %%
# usually takes some time to execute...

# create files for images

cutoff = C * R
temp_image_name = 'img.jpeg'

for index, row in df.iterrows():
    url = row['url']
    name = str(index+1)
    urllib.request.urlretrieve(url, temp_image_name)
    data = open(temp_image_name, 'rb')
    
    s3 = create_client_from_session()
    s3.put_object(Body = data, Bucket=bucket_name, Key=img_folder_name + name + '.jpeg')

    print('{}/{} files added.'.format(name, cutoff), end='\r')
    
    res = (index + 1) % cutoff
    if res == 0:
        break;
        
if os.path.exists(temp_image_name):
    os.remove(temp_image_name)
# Out:
# 225/225 files added.

# %%
def collage(array, ncols=20):
    nindex, height, width, intensity = array.shape
    nrows = nindex//ncols
    assert nindex == nrows*ncols
    result = (
        array
        .reshape(nrows, ncols, height, width, intensity)
        .swapaxes(1, 2)
        .reshape(height*nrows, width*ncols, intensity)
    )
    return result
    
def make_array(bucket, bucket_name):
    l = []
    
    for count, bucket_object in enumerate(bucket.objects.all()):
        if count==0:
            continue
        else:
            print('first=', bucket_object) # displays lexicographically
            key = bucket_object.key
            
            location = create_client().get_bucket_location(Bucket=bucket_name)['LocationConstraint']

            url = 'https://s3-%s.amazonaws.com/%s/%s' % (location, bucket_name, key)
            if '.jpeg' in url:
                response = requests.get(url)
                print(response.status_code)
                if response.status_code == 200:
                    t = BytesIO(response.content)
                    im = Image.open(t)
                    imc = im.convert('RGB')
                    if imc.size == (640, 640):
                        l.append(url)

    l = l[:200]
    
    np_array_list = []
    for url in l:
        print('second=', url) # displays lexicographically
        item = np.asarray(Image.open(BytesIO(requests.get(url).content)).convert('RGB'))
        np_array_list.append(item)
    return np.array(np_array_list)

# %%
print('time: '+ str(datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
# Out:
# time: 2024-06-23 10:32:28

# %%
# usually takes some time to execute...

arr = make_array(bucket, bucket_name)
print('shape', arr.shape)
# Out:
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/1.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/10.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/100.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/101.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/102.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/103.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/104.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/105.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/106.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/107.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/108.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/109.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/11.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/110.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/111.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/112.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/113.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/114.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/115.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/116.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/117.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/118.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/119.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/12.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/120.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/121.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/122.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/123.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/124.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/125.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/126.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/127.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/128.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/129.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/13.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/130.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/131.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/132.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/133.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/134.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/135.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/136.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/137.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/138.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/139.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/14.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/140.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/141.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/142.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/143.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/144.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/145.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/146.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/147.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/148.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/149.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/15.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/150.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/151.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/152.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/153.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/154.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/155.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/156.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/157.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/158.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/159.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/16.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/160.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/161.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/162.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/163.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/164.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/165.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/166.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/167.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/168.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/169.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/17.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/170.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/171.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/172.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/173.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/174.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/175.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/176.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/177.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/178.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/179.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/18.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/180.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/181.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/182.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/183.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/184.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/185.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/186.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/187.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/188.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/189.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/19.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/190.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/191.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/192.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/193.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/194.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/195.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/196.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/197.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/198.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/199.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/2.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/20.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/200.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/201.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/202.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/203.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/204.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/205.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/206.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/207.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/208.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/209.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/21.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/210.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/211.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/212.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/213.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/214.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/215.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/216.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/217.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/218.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/219.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/22.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/220.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/221.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/222.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/223.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/224.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/225.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/23.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/24.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/25.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/26.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/27.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/28.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/29.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/3.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/30.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/31.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/32.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/33.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/34.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/35.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/36.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/37.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/38.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/39.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/4.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/40.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/41.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/42.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/43.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/44.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/45.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/46.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/47.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/48.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/49.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/5.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/50.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/51.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/52.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/53.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/54.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/55.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/56.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/57.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/58.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/59.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/6.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/60.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/61.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/62.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/63.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/64.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/65.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/66.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/67.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/68.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/69.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/7.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/70.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/71.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/72.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/73.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/74.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/75.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/76.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/77.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/78.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/79.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/8.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/80.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/81.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/82.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/83.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/84.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/85.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/86.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/87.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/88.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/89.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/9.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/90.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/91.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/92.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/93.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/94.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/95.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/96.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/97.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/98.jpeg')
# 200
# first= s3.ObjectSummary(bucket_name='spotify-album-collage', key='collage-images/99.jpeg')
# 200
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/1.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/10.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/101.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/102.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/103.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/104.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/105.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/106.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/108.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/109.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/11.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/110.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/111.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/112.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/113.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/114.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/115.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/116.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/117.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/118.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/119.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/12.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/120.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/121.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/123.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/124.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/125.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/126.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/127.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/128.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/129.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/13.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/130.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/131.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/132.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/133.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/134.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/136.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/137.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/138.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/139.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/14.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/140.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/142.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/143.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/144.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/145.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/146.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/147.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/148.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/149.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/15.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/150.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/151.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/152.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/153.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/154.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/155.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/156.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/157.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/158.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/159.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/16.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/162.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/163.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/164.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/165.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/166.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/167.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/168.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/169.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/17.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/170.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/171.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/172.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/173.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/174.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/175.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/176.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/177.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/178.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/179.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/18.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/181.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/182.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/184.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/186.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/188.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/189.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/19.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/191.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/192.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/193.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/194.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/195.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/196.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/197.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/198.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/199.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/2.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/200.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/201.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/202.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/203.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/204.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/205.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/206.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/207.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/208.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/209.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/21.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/210.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/211.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/212.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/213.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/214.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/215.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/216.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/217.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/218.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/219.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/22.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/220.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/221.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/222.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/223.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/224.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/225.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/23.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/25.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/26.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/27.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/28.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/29.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/3.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/30.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/31.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/32.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/33.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/34.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/36.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/37.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/38.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/39.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/4.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/40.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/41.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/42.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/43.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/44.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/45.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/46.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/47.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/48.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/49.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/5.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/50.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/51.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/52.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/53.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/55.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/56.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/57.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/58.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/59.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/6.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/60.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/61.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/62.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/63.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/64.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/65.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/67.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/68.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/7.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/70.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/71.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/72.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/73.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/75.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/76.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/77.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/78.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/79.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/8.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/80.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/81.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/82.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/83.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/84.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/85.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/86.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/87.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/88.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/89.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/9.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/90.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/91.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/92.jpeg
# second= https://s3-us-east-2.amazonaws.com/spotify-album-collage/collage-images/93.jpeg
# shape (200, 640, 640, 3)

# %%
print('time: '+ str(datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
# Out:
# time: 2024-06-23 10:35:30

# %%
result = collage(arr)

# %%
collage_dir = './collages/'
if not os.path.exists(collage_dir):
    os.makedirs(collage_dir)

current_time = str(int(datetime.now().strftime('%Y%m%d%H%M%S')))

file_name = current_time + '_collage-aws-no-plt.jpeg'

file_path = collage_dir + file_name

print(file_path)
# Out:
# ./collages/20240623103530_collage-aws-no-plt.jpeg

# %%
im = Image.fromarray(result)
im.save(file_path)

# %%
print('time: '+ str(datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
# Out:
# time: 2024-06-23 10:35:30

# %%
# delete objects from AWS S3 bucket

bucket.objects.filter(Prefix=img_folder_name).delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '1PZA8ZW9BV3XSMKM',
#    'HostId': 'akKo0t7yYXqK9BNCfWY8ge/J18YOIMko/MHqLmnFspRjH3MGQLKbMTKqXhix6XYpk9wADubFp0kLJOln/l2l5pd/47xlBMywTerBQ24i+8E=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'akKo0t7yYXqK9BNCfWY8ge/J18YOIMko/MHqLmnFspRjH3MGQLKbMTKqXhix6XYpk9wADubFp0kLJOln/l2l5pd/47xlBMywTerBQ24i+8E=',
#     'x-amz-request-id': '1PZA8ZW9BV3XSMKM',
#     'date': 'Sun, 23 Jun 2024 15:35:31 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'collage-images/192.jpeg'},
#    {'Key': 'collage-images/224.jpeg'},
#    {'Key': 'collage-images/115.jpeg'},
#    {'Key': 'collage-images/67.jpeg'},
#    {'Key': 'collage-images/174.jpeg'},
#    {'Key': 'collage-images/82.jpeg'},
#    {'Key': 'collage-images/173.jpeg'},
#    {'Key': 'collage-images/'},
#    {'Key': 'collage-images/116.jpeg'},
#    {'Key': 'collage-images/111.jpeg'},
#    {'Key': 'collage-images/131.jpeg'},
#    {'Key': 'collage-images/209.jpeg'},
#    {'Key': 'collage-images/98.jpeg'},
#    {'Key': 'collage-images/128.jpeg'},
#    {'Key': 'collage-images/176.jpeg'},
#    {'Key': 'collage-images/216.jpeg'},
#    {'Key': 'collage-images/206.jpeg'},
#    {'Key': 'collage-images/18.jpeg'},
#    {'Key': 'collage-images/54.jpeg'},
#    {'Key': 'collage-images/182.jpeg'},
#    {'Key': 'collage-images/103.jpeg'},
#    {'Key': 'collage-images/181.jpeg'},
#    {'Key': 'collage-images/213.jpeg'},
#    {'Key': 'collage-images/62.jpeg'},
#    {'Key': 'collage-images/10.jpeg'},
#    {'Key': 'collage-images/178.jpeg'},
#    {'Key': 'collage-images/43.jpeg'},
#    {'Key': 'collage-images/144.jpeg'},
#    {'Key': 'collage-images/148.jpeg'},
#    {'Key': 'collage-images/90.jpeg'},
#    {'Key': 'collage-images/41.jpeg'},
#    {'Key': 'collage-images/147.jpeg'},
#    {'Key': 'collage-images/66.jpeg'},
#    {'Key': 'collage-images/180.jpeg'},
#    {'Key': 'collage-images/217.jpeg'},
#    {'Key': 'collage-images/48.jpeg'},
#    {'Key': 'collage-images/105.jpeg'},
#    {'Key': 'collage-images/51.jpeg'},
#    {'Key': 'collage-images/204.jpeg'},
#    {'Key': 'collage-images/141.jpeg'},
#    {'Key': 'collage-images/6.jpeg'},
#    {'Key': 'collage-images/13.jpeg'},
#    {'Key': 'collage-images/96.jpeg'},
#    {'Key': 'collage-images/125.jpeg'},
#    {'Key': 'collage-images/154.jpeg'},
#    {'Key': 'collage-images/195.jpeg'},
#    {'Key': 'collage-images/138.jpeg'},
#    {'Key': 'collage-images/60.jpeg'},
#    {'Key': 'collage-images/165.jpeg'},
#    {'Key': 'collage-images/170.jpeg'},
#    {'Key': 'collage-images/150.jpeg'},
#    {'Key': 'collage-images/205.jpeg'},
#    {'Key': 'collage-images/171.jpeg'},
#    {'Key': 'collage-images/89.jpeg'},
#    {'Key': 'collage-images/177.jpeg'},
#    {'Key': 'collage-images/102.jpeg'},
#    {'Key': 'collage-images/15.jpeg'},
#    {'Key': 'collage-images/32.jpeg'},
#    {'Key': 'collage-images/133.jpeg'},
#    {'Key': 'collage-images/3.jpeg'},
#    {'Key': 'collage-images/106.jpeg'},
#    {'Key': 'collage-images/208.jpeg'},
#    {'Key': 'collage-images/120.jpeg'},
#    {'Key': 'collage-images/159.jpeg'},
#    {'Key': 'collage-images/197.jpeg'},
#    {'Key': 'collage-images/64.jpeg'},
#    {'Key': 'collage-images/34.jpeg'},
#    {'Key': 'collage-images/218.jpeg'},
#    {'Key': 'collage-images/107.jpeg'},
#    {'Key': 'collage-images/81.jpeg'},
#    {'Key': 'collage-images/122.jpeg'},
#    {'Key': 'collage-images/95.jpeg'},
#    {'Key': 'collage-images/198.jpeg'},
#    {'Key': 'collage-images/163.jpeg'},
#    {'Key': 'collage-images/172.jpeg'},
#    {'Key': 'collage-images/78.jpeg'},
#    {'Key': 'collage-images/27.jpeg'},
#    {'Key': 'collage-images/19.jpeg'},
#    {'Key': 'collage-images/29.jpeg'},
#    {'Key': 'collage-images/7.jpeg'},
#    {'Key': 'collage-images/123.jpeg'},
#    {'Key': 'collage-images/179.jpeg'},
#    {'Key': 'collage-images/30.jpeg'},
#    {'Key': 'collage-images/117.jpeg'},
#    {'Key': 'collage-images/191.jpeg'},
#    {'Key': 'collage-images/99.jpeg'},
#    {'Key': 'collage-images/130.jpeg'},
#    {'Key': 'collage-images/187.jpeg'},
#    {'Key': 'collage-images/55.jpeg'},
#    {'Key': 'collage-images/73.jpeg'},
#    {'Key': 'collage-images/77.jpeg'},
#    {'Key': 'collage-images/94.jpeg'},
#    {'Key': 'collage-images/40.jpeg'},
#    {'Key': 'collage-images/36.jpeg'},
#    {'Key': 'collage-images/42.jpeg'},
#    {'Key': 'collage-images/28.jpeg'},
#    {'Key': 'collage-images/71.jpeg'},
#    {'Key': 'collage-images/35.jpeg'},
#    {'Key': 'collage-images/113.jpeg'},
#    {'Key': 'collage-images/169.jpeg'},
#    {'Key': 'collage-images/188.jpeg'},
#    {'Key': 'collage-images/33.jpeg'},
#    {'Key': 'collage-images/45.jpeg'},
#    {'Key': 'collage-images/76.jpeg'},
#    {'Key': 'collage-images/124.jpeg'},
#    {'Key': 'collage-images/22.jpeg'},
#    {'Key': 'collage-images/152.jpeg'},
#    {'Key': 'collage-images/202.jpeg'},
#    {'Key': 'collage-images/135.jpeg'},
#    {'Key': 'collage-images/136.jpeg'},
#    {'Key': 'collage-images/183.jpeg'},
#    {'Key': 'collage-images/104.jpeg'},
#    {'Key': 'collage-images/58.jpeg'},
#    {'Key': 'collage-images/129.jpeg'},
#    {'Key': 'collage-images/61.jpeg'},
#    {'Key': 'collage-images/38.jpeg'},
#    {'Key': 'collage-images/69.jpeg'},
#    {'Key': 'collage-images/137.jpeg'},
#    {'Key': 'collage-images/219.jpeg'},
#    {'Key': 'collage-images/80.jpeg'},
#    {'Key': 'collage-images/21.jpeg'},
#    {'Key': 'collage-images/153.jpeg'},
#    {'Key': 'collage-images/44.jpeg'},
#    {'Key': 'collage-images/39.jpeg'},
#    {'Key': 'collage-images/2.jpeg'},
#    {'Key': 'collage-images/56.jpeg'},
#    {'Key': 'collage-images/101.jpeg'},
#    {'Key': 'collage-images/155.jpeg'},
#    {'Key': 'collage-images/50.jpeg'},
#    {'Key': 'collage-images/158.jpeg'},
#    {'Key': 'collage-images/75.jpeg'},
#    {'Key': 'collage-images/210.jpeg'},
#    {'Key': 'collage-images/223.jpeg'},
#    {'Key': 'collage-images/207.jpeg'},
#    {'Key': 'collage-images/12.jpeg'},
#    {'Key': 'collage-images/151.jpeg'},
#    {'Key': 'collage-images/127.jpeg'},
#    {'Key': 'collage-images/31.jpeg'},
#    {'Key': 'collage-images/161.jpeg'},
#    {'Key': 'collage-images/211.jpeg'},
#    {'Key': 'collage-images/225.jpeg'},
#    {'Key': 'collage-images/59.jpeg'},
#    {'Key': 'collage-images/114.jpeg'},
#    {'Key': 'collage-images/24.jpeg'},
#    {'Key': 'collage-images/189.jpeg'},
#    {'Key': 'collage-images/212.jpeg'},
#    {'Key': 'collage-images/108.jpeg'},
#    {'Key': 'collage-images/46.jpeg'},
#    {'Key': 'collage-images/1.jpeg'},
#    {'Key': 'collage-images/146.jpeg'},
#    {'Key': 'collage-images/199.jpeg'},
#    {'Key': 'collage-images/126.jpeg'},
#    {'Key': 'collage-images/166.jpeg'},
#    {'Key': 'collage-images/134.jpeg'},
#    {'Key': 'collage-images/86.jpeg'},
#    {'Key': 'collage-images/140.jpeg'},
#    {'Key': 'collage-images/222.jpeg'},
#    {'Key': 'collage-images/164.jpeg'},
#    {'Key': 'collage-images/79.jpeg'},
#    {'Key': 'collage-images/193.jpeg'},
#    {'Key': 'collage-images/92.jpeg'},
#    {'Key': 'collage-images/11.jpeg'},
#    {'Key': 'collage-images/142.jpeg'},
#    {'Key': 'collage-images/145.jpeg'},
#    {'Key': 'collage-images/88.jpeg'},
#    {'Key': 'collage-images/63.jpeg'},
#    {'Key': 'collage-images/215.jpeg'},
#    {'Key': 'collage-images/121.jpeg'},
#    {'Key': 'collage-images/57.jpeg'},
#    {'Key': 'collage-images/87.jpeg'},
#    {'Key': 'collage-images/220.jpeg'},
#    {'Key': 'collage-images/49.jpeg'},
#    {'Key': 'collage-images/160.jpeg'},
#    {'Key': 'collage-images/47.jpeg'},
#    {'Key': 'collage-images/85.jpeg'},
#    {'Key': 'collage-images/110.jpeg'},
#    {'Key': 'collage-images/119.jpeg'},
#    {'Key': 'collage-images/68.jpeg'},
#    {'Key': 'collage-images/185.jpeg'},
#    {'Key': 'collage-images/201.jpeg'},
#    {'Key': 'collage-images/4.jpeg'},
#    {'Key': 'collage-images/190.jpeg'},
#    {'Key': 'collage-images/52.jpeg'},
#    {'Key': 'collage-images/26.jpeg'},
#    {'Key': 'collage-images/168.jpeg'},
#    {'Key': 'collage-images/5.jpeg'},
#    {'Key': 'collage-images/132.jpeg'},
#    {'Key': 'collage-images/214.jpeg'},
#    {'Key': 'collage-images/184.jpeg'},
#    {'Key': 'collage-images/91.jpeg'},
#    {'Key': 'collage-images/53.jpeg'},
#    {'Key': 'collage-images/9.jpeg'},
#    {'Key': 'collage-images/20.jpeg'},
#    {'Key': 'collage-images/175.jpeg'},
#    {'Key': 'collage-images/83.jpeg'},
#    {'Key': 'collage-images/143.jpeg'},
#    {'Key': 'collage-images/74.jpeg'},
#    {'Key': 'collage-images/186.jpeg'},
#    {'Key': 'collage-images/93.jpeg'},
#    {'Key': 'collage-images/157.jpeg'},
#    {'Key': 'collage-images/221.jpeg'},
#    {'Key': 'collage-images/162.jpeg'},
#    {'Key': 'collage-images/84.jpeg'},
#    {'Key': 'collage-images/118.jpeg'},
#    {'Key': 'collage-images/25.jpeg'},
#    {'Key': 'collage-images/112.jpeg'},
#    {'Key': 'collage-images/196.jpeg'},
#    {'Key': 'collage-images/100.jpeg'},
#    {'Key': 'collage-images/203.jpeg'},
#    {'Key': 'collage-images/194.jpeg'},
#    {'Key': 'collage-images/37.jpeg'},
#    {'Key': 'collage-images/16.jpeg'},
#    {'Key': 'collage-images/156.jpeg'},
#    {'Key': 'collage-images/97.jpeg'},
#    {'Key': 'collage-images/109.jpeg'},
#    {'Key': 'collage-images/8.jpeg'},
#    {'Key': 'collage-images/65.jpeg'},
#    {'Key': 'collage-images/72.jpeg'},
#    {'Key': 'collage-images/200.jpeg'},
#    {'Key': 'collage-images/139.jpeg'},
#    {'Key': 'collage-images/70.jpeg'},
#    {'Key': 'collage-images/23.jpeg'},
#    {'Key': 'collage-images/167.jpeg'},
#    {'Key': 'collage-images/17.jpeg'},
#    {'Key': 'collage-images/14.jpeg'},
#    {'Key': 'collage-images/149.jpeg'}]}]
